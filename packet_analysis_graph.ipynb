# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as ticker

# %%
df= pd.read_csv(r"/logs/analyzed_data.csv")

#print(df.sort_values(by=["QOS_LEVEL","FREQUENCY", "PACKET_SIZE", "NUM_CLIENTS"]).to_string())

qos0= df['QOS_LEVEL']==0
qos1= df['QOS_LEVEL']==1
qos2= df['QOS_LEVEL']==2

c1= df['NUM_CLIENTS']==1
c2= df['NUM_CLIENTS']==2
c3= df['NUM_CLIENTS']==3
c4= df['NUM_CLIENTS']==4

small = df['PACKET_SIZE']==1250
medium= df['PACKET_SIZE']==12500
large= df['PACKET_SIZE']==125000

f1=df['FREQUENCY']==1
f10=df['FREQUENCY']==10
f100=df['FREQUENCY']==100

df['RTT Mean'] = np.log10(df['RTT Mean'])

min_rtt_exp = -2#np.floor(df['RTT Mean'].min()) 
max_rtt_exp = np.ceil(df['RTT Mean'].max())

if (min_rtt_exp < 0):
    df['RTT Mean'] = df['RTT Mean'] - min_rtt_exp

df.loc[df['RTT Mean'] < 0, ['RTT Mean',]] = 0

print(df['RTT Mean'].min())
print(df['RTT Mean'].max())
#print(df[qos1&f10&medium&c1]['RTT Mean'].values[0])



# mpl.rcParams['legend.fontsize'] = 40
# plt.rcParams.update({'font.size': 30})
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x_labels=['1','10','100']

manual_ticks = [2.5, 7, 12.5, 17, 22.5, 27]
freqs = [7, 12.5, 22.5]


x1=[manual_ticks[0],manual_ticks[2],manual_ticks[4],manual_ticks[0],manual_ticks[2],manual_ticks[4],manual_ticks[0],manual_ticks[2],manual_ticks[4]] #frequency
y1=[manual_ticks[0],manual_ticks[0],manual_ticks[0],manual_ticks[2],manual_ticks[2],manual_ticks[2],manual_ticks[4],manual_ticks[4],manual_ticks[4]] #payload
z1= [df[qos0&f1&large&c2]['RTT Mean'].values[0],df[qos0&f10&large&c2]['RTT Mean'].values[0],df[qos0&f100&large&c2]['RTT Mean'].values[0],df[qos0&f1&medium&c2]['RTT Mean'].values[0],df[qos0&f10&medium&c2]['RTT Mean'].values[0],df[qos0&f100&medium&c2]['RTT Mean'].values[0],df[qos0&f1&small&c2]['RTT Mean'].values[0],df[qos0&f10&small&c2]['RTT Mean'].values[0],df[qos0&f100&small&c2]['RTT Mean'].values[0]]
ax.bar3d(x1, y1, np.zeros(len(x1)),np.ones(len(x1))*2,np.ones(len(x1))*2,z1,color='orange',alpha=0.5)


x2=[manual_ticks[1],manual_ticks[3],manual_ticks[5],manual_ticks[1],manual_ticks[3],manual_ticks[5],manual_ticks[1],manual_ticks[3],manual_ticks[5]] #frequency
y2=[manual_ticks[0],manual_ticks[0],manual_ticks[0],manual_ticks[2],manual_ticks[2],manual_ticks[2],manual_ticks[4],manual_ticks[4],manual_ticks[4]] #payload
z2= [df[qos0&f1&large&c4]['RTT Mean'].values[0],df[qos0&f10&large&c4]['RTT Mean'].values[0],df[qos0&f100&large&c4]['RTT Mean'].values[0],df[qos0&f1&medium&c4]['RTT Mean'].values[0],df[qos0&f10&medium&c4]['RTT Mean'].values[0],df[qos0&f100&medium&c4]['RTT Mean'].values[0],df[qos0&f1&small&c4]['RTT Mean'].values[0],df[qos0&f10&small&c4]['RTT Mean'].values[0],df[qos0&f100&small&c4]['RTT Mean'].values[0]]
ax.bar3d(x2, y2, np.zeros(len(x2)),np.ones(len(x2))*2,np.ones(len(x2))*2,z2,color='green',alpha=0.5)


x3=[manual_ticks[0],manual_ticks[2],manual_ticks[4],manual_ticks[0],manual_ticks[2],manual_ticks[4],manual_ticks[0],manual_ticks[2],manual_ticks[4]] #frequency
y3=[manual_ticks[1],manual_ticks[1],manual_ticks[1],manual_ticks[3],manual_ticks[3],manual_ticks[3],manual_ticks[5],manual_ticks[5],manual_ticks[5]] #payload
z3= [df[qos0&f1&large&c1]['RTT Mean'].values[0],df[qos0&f10&large&c1]['RTT Mean'].values[0],df[qos0&f100&large&c1]['RTT Mean'].values[0],df[qos0&f1&medium&c1]['RTT Mean'].values[0],df[qos0&f10&medium&c1]['RTT Mean'].values[0],df[qos0&f100&medium&c1]['RTT Mean'].values[0],df[qos0&f1&small&c1]['RTT Mean'].values[0],df[qos0&f10&small&c1]['RTT Mean'].values[0],df[qos0&f100&small&c1]['RTT Mean'].values[0]]
ax.bar3d(x3, y3, np.zeros(len(x3)),np.ones(len(x3))*2,np.ones(len(x3))*2,z3,color='red',alpha=0.5) 


x3=[manual_ticks[1],manual_ticks[3],manual_ticks[5],manual_ticks[1],manual_ticks[3],manual_ticks[5],manual_ticks[1],manual_ticks[3],manual_ticks[5]] #frequency
y3=[manual_ticks[1],manual_ticks[1],manual_ticks[1],manual_ticks[3],manual_ticks[3],manual_ticks[3],manual_ticks[5],manual_ticks[5],manual_ticks[5]] #payload
z4=[df[qos0&f1&large&c3]['RTT Mean'].values[0],df[qos0&f10&large&c3]['RTT Mean'].values[0],df[qos0&f100&large&c3]['RTT Mean'].values[0],df[qos0&f1&medium&c3]['RTT Mean'].values[0],df[qos0&f10&medium&c3]['RTT Mean'].values[0],df[qos0&f100&medium&c3]['RTT Mean'].values[0],df[qos0&f1&small&c3]['RTT Mean'].values[0],df[qos0&f10&small&c3]['RTT Mean'].values[0],df[qos0&f100&small&c3]['RTT Mean'].values[0]]
ax.bar3d(x3, y3, np.zeros(len(x3)),np.ones(len(x3))*2,np.ones(len(x3))*2,z4,color='blue',alpha=0.5)


ax.plot([10,10],[0,30],color='grey',linestyle='--',alpha=0.4)
ax.plot([20,20],[0,30],color='grey',linestyle='--',alpha=0.4)
ax.plot([0,30],[10,10],color='grey',linestyle='--',alpha=0.4)
ax.plot([0,30],[20,20],color='grey',linestyle='--',alpha=0.4)
ax.grid(True)
ax.set_xticks(ticks=[5.5,15.5,25.5], labels=x_labels,fontsize=40)
ax.set_yticks([5.5,15.5,25.5],labels=['125','12.5','1.25'],fontsize=40)
ax.tick_params(pad=15)

zticks_minor_subs = np.arange(2, 10)
zticks_major_subs = np.arange(min_rtt_exp, max_rtt_exp, dtype=float)
ax.zaxis.set_minor_locator(ticker.FixedLocator(np.array([y - min_rtt_exp + np.log10(x) for y in np.arange(min_rtt_exp, max_rtt_exp, dtype=float) for x in zticks_subs])))
ax.zaxis.set_major_locator(ticker.FixedLocator(zticks_major_subs - min_rtt_exp))

def log_tick_formatter(val, pos=None):
    return r"$10^{%d}$" % int(val+min_rtt_exp)
ax.zaxis.set_major_formatter(ticker.FuncFormatter(log_tick_formatter))
ax.tick_params(axis='z', labelsize=40, pad=25)
ax.set_zlim([0,3])
#ax.set_zlim([0,None])


ax.set_xlim([0,30])
ax.set_ylim([0,30])

# ax.set_zlim([0,max(z1+z2+z3+z4)+1])
b1 = plt.Rectangle((0, 0), 1, 1, fc="red")
b2 = plt.Rectangle((0, 0), 1, 1, fc="orange")
b3 = plt.Rectangle((0, 0), 1, 1, fc="blue")
b4 = plt.Rectangle((0, 0), 1, 1, fc="green")
ax.legend([b1, b2, b3, b4], ['1 Client', '2 Clients','3 Clients', '4 Clients'],fontsize=45,bbox_to_anchor=(0.95,0.7))
ax.set_xlabel("Data Rate (Hz)",fontsize=50, labelpad=40)
ax.set_zlabel("Average RTT (s)",fontsize=50, labelpad=55)
ax.set_ylabel("Payload Size (KB)",fontsize=50, labelpad=50)
ax.set_title("QoS 0",fontsize=70, y=1.0, pad=-200, fontweight='bold')
ax.view_init(25, 500)


figure = plt.gcf()  # get current figure
figure.set_size_inches(64, 36) # set figure's size manually to your full screen (32x18)
plt.savefig(r"/logs/QoS0AvgRTT.pdf", format="pdf", bbox_inches="tight")
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x_labels=['1','10','100']

x1=[2.5,12.5,22.5,2.5,12.5,22.5,2.5,12.5,22.5]
y1=[2.5,2.5,2.5,12.5,12.5,12.5,22.5,22.5,22.5]
z1= [df[qos1&f1&large&c2]['RTT Mean'].values[0],df[qos1&f10&large&c2]['RTT Mean'].values[0],df[qos1&f100&large&c2]['RTT Mean'].values[0],df[qos1&f1&medium&c2]['RTT Mean'].values[0],df[qos1&f10&medium&c2]['RTT Mean'].values[0],df[qos1&f100&medium&c2]['RTT Mean'].values[0],df[qos1&f1&small&c2]['RTT Mean'].values[0],df[qos1&f10&small&c2]['RTT Mean'].values[0],df[qos1&f100&small&c2]['RTT Mean'].values[0]]
ax.bar3d(x1, y1, np.zeros(len(x1)),np.ones(len(x1))*2,np.ones(len(x1))*2,z1,color='orange',alpha=0.5)

x2=[7,17,27,7,17,27,7,17,27] #frequency
y2=[2.5,2.5,2.5,12.5,12.5,12.5,22.5,22.5,22.5]  #payload
z2= [df[qos1&f1&large&c4]['RTT Mean'].values[0],df[qos1&f10&large&c4]['RTT Mean'].values[0],df[qos1&f100&large&c4]['RTT Mean'].values[0],df[qos1&f1&medium&c4]['RTT Mean'].values[0],df[qos1&f10&medium&c4]['RTT Mean'].values[0],df[qos1&f100&medium&c4]['RTT Mean'].values[0],df[qos1&f1&small&c4]['RTT Mean'].values[0],df[qos1&f10&small&c4]['RTT Mean'].values[0],df[qos1&f100&small&c4]['RTT Mean'].values[0]]
ax.bar3d(x2, y2, np.zeros(len(x2)),np.ones(len(x2))*2,np.ones(len(x2))*2,z2,color='green',alpha=0.5)


x3=[2.5,12.5,22.5,2.5,12.5,22.5,2.5,12.5,22.5] #frequency
y3=[7,7,7,17,17,17,27,27,27] # payload
z3= [df[qos1&f1&large&c1]['RTT Mean'].values[0],df[qos1&f10&large&c1]['RTT Mean'].values[0],df[qos1&f100&large&c1]['RTT Mean'].values[0],df[qos1&f1&medium&c1]['RTT Mean'].values[0],df[qos1&f10&medium&c1]['RTT Mean'].values[0],df[qos1&f100&medium&c1]['RTT Mean'].values[0],df[qos1&f1&small&c1]['RTT Mean'].values[0],df[qos1&f10&small&c1]['RTT Mean'].values[0],df[qos1&f100&small&c1]['RTT Mean'].values[0]]
ax.bar3d(x3, y3, np.zeros(len(x3)),np.ones(len(x3))*2,np.ones(len(x3))*2,z3,color='red',alpha=0.5) 


x3=[7,17,27,7,17,27,7,17,27]
y3=[7,7,7,17,17,17,27,27,27]
z4=[df[qos1&f1&large&c3]['RTT Mean'].values[0],df[qos1&f10&large&c3]['RTT Mean'].values[0],df[qos1&f100&large&c3]['RTT Mean'].values[0],df[qos1&f1&medium&c3]['RTT Mean'].values[0],df[qos1&f10&medium&c3]['RTT Mean'].values[0],df[qos1&f100&medium&c3]['RTT Mean'].values[0],df[qos1&f1&small&c3]['RTT Mean'].values[0],df[qos1&f10&small&c3]['RTT Mean'].values[0],df[qos1&f100&small&c3]['RTT Mean'].values[0]]
ax.bar3d(x3, y3, np.zeros(len(x3)),np.ones(len(x3))*2,np.ones(len(x3))*2,z4,color='blue',alpha=0.5)


ax.plot([10,10],[0,30],color='grey',linestyle='--',alpha=0.4)
ax.plot([20,20],[0,30],color='grey',linestyle='--',alpha=0.4)
ax.plot([0,30],[10,10],color='grey',linestyle='--',alpha=0.4)
ax.plot([0,30],[20,20],color='grey',linestyle='--',alpha=0.4)
ax.grid(True)
ax.set_xticks(ticks=[5.5,15.5,25.5], labels=x_labels,fontsize=40)
ax.set_yticks([5.5,15.5,25.5],labels=['125','12.5','1.25'],fontsize=40)

zticks_minor_subs = np.arange(2, 10)
zticks_major_subs = np.arange(min_rtt_exp, max_rtt_exp, dtype=float)
ax.zaxis.set_minor_locator(ticker.FixedLocator(np.array([y - min_rtt_exp + np.log10(x) for y in np.arange(min_rtt_exp, max_rtt_exp, dtype=float) for x in zticks_subs])))
ax.zaxis.set_major_locator(ticker.FixedLocator(zticks_major_subs - min_rtt_exp))

def log_tick_formatter(val, pos=None):
    return r"$10^{%d}$" % int(val+min_rtt_exp)
ax.zaxis.set_major_formatter(ticker.FuncFormatter(log_tick_formatter))
ax.tick_params(axis='z', labelsize=40, pad=25)
ax.set_zlim([0,3.5])


ax.set_xlim([0,30])
ax.set_ylim([0,30])
# # ax.set_zlim([0,max(z1+z2+z3+z4)+1])


b1 = plt.Rectangle((0, 0), 1, 1, fc="red")
b2 = plt.Rectangle((0, 0), 1, 1, fc="orange")
b3 = plt.Rectangle((0, 0), 1, 1, fc="blue")
b4 = plt.Rectangle((0, 0), 1, 1, fc="green")
ax.legend([b1, b2, b3, b4], ['1 Client', '2 Clients','3 Clients', '4 Clients'],fontsize=45,bbox_to_anchor=(0.95,0.7))


ax.set_xlabel("Data Rate (Hz)",fontsize=50, labelpad=40)
ax.set_zlabel("Average RTT (s)",fontsize=50, labelpad=55)
ax.set_ylabel("Payload Size (KB)",fontsize=50, labelpad=50)
ax.set_title("QoS 1",fontsize=70, y=1.0, pad=-200, fontweight='bold')
ax.view_init(25, 500)
figure = plt.gcf()  # get current figure
figure.set_size_inches(64, 36) # set figure's size manually to your full screen (32x18)
plt.savefig(r"/logs/qos1AvgRTT.pdf", format="pdf", bbox_inches="tight")

plt.show()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x_labels=['1','10','100']

x1=[2.5,12.5,22.5,2.5,12.5,22.5,2.5,12.5,22.5]
y1=[2.5,2.5,2.5,12.5,12.5,12.5,22.5,22.5,22.5]
z1= [df[qos2&f1&large&c2]['RTT Mean'].values[0],df[qos2&f10&large&c2]['RTT Mean'].values[0],df[qos2&f100&large&c2]['RTT Mean'].values[0],df[qos2&f1&medium&c2]['RTT Mean'].values[0],df[qos2&f10&medium&c2]['RTT Mean'].values[0],df[qos2&f100&medium&c2]['RTT Mean'].values[0],df[qos2&f1&small&c2]['RTT Mean'].values[0],df[qos2&f10&small&c2]['RTT Mean'].values[0],df[qos2&f100&small&c2]['RTT Mean'].values[0]]
ax.bar3d(x1, y1, np.zeros(len(x1)),np.ones(len(x1))*2,np.ones(len(x1))*2,z1,color='orange',alpha=0.5)


x2=[7,17,27,7,17,27,7,17,27] #frequency
y2=[2.5,2.5,2.5,12.5,12.5,12.5,22.5,22.5,22.5]  #payload
z2= [df[qos2&f1&large&c4]['RTT Mean'].values[0],df[qos2&f10&large&c4]['RTT Mean'].values[0],df[qos2&f100&large&c4]['RTT Mean'].values[0],df[qos2&f1&medium&c4]['RTT Mean'].values[0],df[qos2&f10&medium&c4]['RTT Mean'].values[0],df[qos2&f100&medium&c4]['RTT Mean'].values[0],df[qos2&f1&small&c4]['RTT Mean'].values[0],df[qos2&f10&small&c4]['RTT Mean'].values[0],df[qos2&f100&small&c4]['RTT Mean'].values[0]]
ax.bar3d(x2, y2, np.zeros(len(x2)),np.ones(len(x2))*2,np.ones(len(x2))*2,z2,color='green',alpha=0.5)

x3=[2.5,12.5,22.5,2.5,12.5,22.5,2.5,12.5,22.5] #frequency
y3=[7,7,7,17,17,17,27,27,27] # payload
z3= [df[qos2&f1&large&c1]['RTT Mean'].values[0],df[qos2&f10&large&c1]['RTT Mean'].values[0],df[qos2&f100&large&c1]['RTT Mean'].values[0],df[qos2&f1&medium&c1]['RTT Mean'].values[0],df[qos2&f10&medium&c1]['RTT Mean'].values[0],df[qos2&f100&medium&c1]['RTT Mean'].values[0],df[qos2&f1&small&c1]['RTT Mean'].values[0],df[qos2&f10&small&c1]['RTT Mean'].values[0],df[qos2&f100&small&c1]['RTT Mean'].values[0]]
ax.bar3d(x3, y3, np.zeros(len(x3)),np.ones(len(x3))*2,np.ones(len(x3))*2,z3,color='red',alpha=0.5) 


x3=[7,17,27,7,17,27,7,17,27]
y3=[7,7,7,17,17,17,27,27,27]
z4=[df[qos2&f1&large&c3]['RTT Mean'].values[0],df[qos2&f10&large&c3]['RTT Mean'].values[0],df[qos2&f100&large&c3]['RTT Mean'].values[0],df[qos2&f1&medium&c3]['RTT Mean'].values[0],df[qos2&f10&medium&c3]['RTT Mean'].values[0],df[qos2&f100&medium&c3]['RTT Mean'].values[0],df[qos2&f1&small&c3]['RTT Mean'].values[0],df[qos2&f10&small&c3]['RTT Mean'].values[0],df[qos2&f100&small&c3]['RTT Mean'].values[0]]
ax.bar3d(x3, y3, np.zeros(len(x3)),np.ones(len(x3))*2,np.ones(len(x3))*2,z4,color='blue',alpha=0.5)


ax.plot([10,10],[0,30],color='grey',linestyle='--',alpha=0.4)
ax.plot([20,20],[0,30],color='grey',linestyle='--',alpha=0.4)
ax.plot([0,30],[10,10],color='grey',linestyle='--',alpha=0.4)
ax.plot([0,30],[20,20],color='grey',linestyle='--',alpha=0.4)
ax.grid(True)
ax.set_xticks(ticks=[5.5,15.5,25.5], labels=x_labels,fontsize=40)
ax.set_yticks([5.5,15.5,25.5],labels=['125','12.5','1.25'],fontsize=40)

zticks_minor_subs = np.arange(2, 10)
zticks_major_subs = np.arange(min_rtt_exp, max_rtt_exp, dtype=float)
ax.zaxis.set_minor_locator(ticker.FixedLocator(np.array([y - min_rtt_exp + np.log10(x) for y in np.arange(min_rtt_exp, max_rtt_exp, dtype=float) for x in zticks_subs])))
ax.zaxis.set_major_locator(ticker.FixedLocator(zticks_major_subs - min_rtt_exp))

def log_tick_formatter(val, pos=None):
    return r"$10^{%d}$" % int(val+min_rtt_exp)
ax.zaxis.set_major_formatter(ticker.FuncFormatter(log_tick_formatter))
ax.tick_params(axis='z', labelsize=40, pad=25 )
ax.set_zlim([0,4])

ax.set_xlim([0,30])
ax.set_ylim([0,30])


b1 = plt.Rectangle((0, 0), 1, 1, fc="red")
b2 = plt.Rectangle((0, 0), 1, 1, fc="orange")
b3 = plt.Rectangle((0, 0), 1, 1, fc="blue")
b4 = plt.Rectangle((0, 0), 1, 1, fc="green")
ax.legend([b1, b2, b3, b4], ['1 Client', '2 Clients','3 Clients', '4 Clients'],fontsize=45,bbox_to_anchor=(0.95,0.7))


ax.set_xlabel("Data Rate (Hz)",fontsize=50, labelpad=40)
ax.set_zlabel("Average RTT (s)",fontsize=50, labelpad=55)
ax.set_ylabel("Payload Size (KB)",fontsize=50, labelpad=50)
ax.set_title("QoS 2",fontsize=70, y=1.0, pad=-200, fontweight='bold')
ax.view_init(25, 500)
figure = plt.gcf()  # get current figure
figure.set_size_inches(64, 36) # set figure's size manually to your full screen (32x18)

plt.savefig(r"/logs/qos2AvgRTT.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# 0.0
# 3.6781559980026235

# %%
# Out:
# array([2.e-06, 3.e-06, 4.e-06, 5.e-06, 6.e-06, 7.e-06, 8.e-06, 9.e-06,
#        2.e-05, 3.e-05, 4.e-05, 5.e-05, 6.e-05, 7.e-05, 8.e-05, 9.e-05,
#        2.e-04, 3.e-04, 4.e-04, 5.e-04, 6.e-04, 7.e-04, 8.e-04, 9.e-04,
#        2.e-03, 3.e-03, 4.e-03, 5.e-03, 6.e-03, 7.e-03, 8.e-03, 9.e-03,
#        2.e-02, 3.e-02, 4.e-02, 5.e-02, 6.e-02, 7.e-02, 8.e-02, 9.e-02,
#        2.e-01, 3.e-01, 4.e-01, 5.e-01, 6.e-01, 7.e-01, 8.e-01, 9.e-01,
#        2.e+00, 3.e+00, 4.e+00, 5.e+00, 6.e+00, 7.e+00, 8.e+00, 9.e+00,
#        2.e+01, 3.e+01, 4.e+01, 5.e+01, 6.e+01, 7.e+01, 8.e+01, 9.e+01,
#        2.e+02, 3.e+02, 4.e+02, 5.e+02, 6.e+02, 7.e+02, 8.e+02, 9.e+02,
#        2.e+03, 3.e+03, 4.e+03, 5.e+03, 6.e+03, 7.e+03, 8.e+03, 9.e+03])
